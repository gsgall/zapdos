# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./0.25W/argon_regulation_out.csv")

# %%
length = 30e-3
depth = 1e-3
end_idx = 180
periods = 14000
plt.figure()
# for i in range(periods):
#   plt.axvline(i * 1 / 13.56e6 + 3.7e-9, linestyle="dashed", c="k")
steps_per_period = int(5 * (1 / 13.56e6) / 1e-9) + 1
plt.plot(data["time"], data["mean_periodic_power"])
plt.plot(data["time"][:-steps_per_period], data["multi_period"][steps_per_period:])
# plt.ylim(bottom=0.2)
# plt.xlim(left=9.99e-4, right=1e-3)
plt.xlabel("Time [s]")
plt.ylabel("Average Power Deposition [W]")
# plt.axvline(100 / 13.56e6)
# plt.xlim(left=3e-5, right=4e-5)
plt.show()


plt.figure()
plt.plot(data["time"], data["voltage"])
plt.xlabel("Time [s]")
plt.ylabel("Average Power Deposition [W]")
plt.show()


plt.figure()
plt.plot(data["time"], data["total_electron_density"], label="e")
plt.plot(data["time"], data["total_Ar+_density"], label="Ar+")
# plt.plot(data["time"], data["total_Ar*_density"], label="Ar*")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/mambaforge3/envs/hw/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total_electron_density'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
